# %% [markdown]
# <a href="https://colab.research.google.com/github/Makhmudov005/-/blob/main/3_1_fayllar_bilan_ishlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93 (from 1)
# Receiving objects: 100% (145/145), 9.72 MiB | 10.44 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
df2 = pd.read_excel('praktikum_datasets/E-Commerce-Dataset.xlsx', index_col = 0, names=['Birinchi hudud', 'Ikkinchi hudud', 'Uchunchi hudud'])
df2.head()
# Out:
#     Birinchi hudud        Ikkinchi hudud                      Uchunchi hudud
# NaN           Data              Variable                         Discerption
# NaN         E Comm            CustomerID                  Unique customer ID
# NaN         E Comm                 Churn                          Churn Flag
# NaN         E Comm                Tenure  Tenure of customer in organization
# NaN         E Comm  PreferredLoginDevice  Preferred login device of customer

# %%
df3 = pd.read_excel('praktikum_datasets/uzbekistan.xlsx', index_col = 0 , names = ['hudud', 'maydon', 'aholi'])
df3
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df3.to_csv('new_uzb.csv')
